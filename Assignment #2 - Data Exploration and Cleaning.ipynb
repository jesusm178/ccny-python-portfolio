# %% [markdown]
# # Assignment #2: Data Exploration
#
# In this assignment, you will demonstrate your knowledge of the Python and Pandas skills we've learned so far. These include:
#
# - Getting an overview of your data
# - Extracting columns
# - Removing duplicates from your data
# - Creating a subset of your data by matching a string
# - Getting a random sample of your data
# - Sorting your data
# - Getting fundamental statistical information of a series, such as the mean and median
#
# You will not need to formulate or answer a research question for this assignment. You simply need to demonstrate your ability to perform specific operations on the data set you have selected. In the next assignment, your midterm, you will create a narrative exploration of the data using many of the same methods, but in such a way as to use narrative along with data analysis to answer a research question.
#
# You may use the data set you imported in assignment #1, or you may choose another data set. That means that you can reuse code you wrote in Assignment #1 to import the data.
#
# In the below notebook, I will ask for you to perform a task. Each task will be followed by one or more blank code cells. Use as many cells as you need to complete the task. If you know some other way to complete the task with Python and/or Pandas that is not the way we learned in class, that is also acceptable. Feel free to use Google searches to refresh your memory as to how to perform each task. You will also likely wish to consult the class notebooks, which can be found in [our class repository on GitHub](https://github.com/sha256rma/foundations-of-data-science).
#
# If your data set does not have a needed form of data for a task, write code that would perform the task if a column with that data existed, and provide an explanation as a comment or markdown cell.
#
# You may receive partial credit for some incomplete or incorrect answers. Please feel free to add comments about your thought process, which will make it more likely that you will receive partial credit.
#
# The last cell is a bonus. You will not be penalized for not attempting or completing it.
#
# -----

# %% [markdown]
# Import Pandas and read your data in as a data frame. Assign the data frame to a variable, such as `df`.

# %%
import pandas as pd
df = pd.read_csv('shades.csv')
df
# Out:
#      Unnamed: 0       brand brand_short     product product_short     hex  \
# 0             0  Maybelline          mb      Fit Me           fmf  f3cfb3
# 1             1  Maybelline          mb      Fit Me           fmf  ffe3c2
# 2             2  Maybelline          mb      Fit Me           fmf  ffe0cd
# 3             3  Maybelline          mb      Fit Me           fmf  ffd3be
# 4             4  Maybelline          mb      Fit Me           fmf  bd9584
# ..          ...         ...         ...         ...           ...     ...
# 620         620     L'Oréal          lo  True Match           tms  eecfba
# 621         621     L'Oréal          lo  True Match           tms  e8c7b8
# 622         622     L'Oréal          lo  True Match           tms  f0cbb9
# 623         623     L'Oréal          lo  True Match           tms  e9c4b1
# 624         624     L'Oréal          lo  True Match           tms  eabea1
#
#         H     S     V   L  group
# 0    26.0  0.26  0.95  86      2
# 1    32.0  0.24  1.00  92      2
# 2    23.0  0.20  1.00  91      2
# 3    19.0  0.25  1.00  88      2
# 4    18.0  0.30  0.74  65      2
# ..    ...   ...   ...  ..    ...
# 620  24.0  0.22  0.93  85      7
# 621  19.0  0.21  0.91  83      7
# 622  20.0  0.23  0.94  85      7
# 623  20.0  0.24  0.91  82      7
# 624  24.0  0.31  0.92  80      7
#
# [625 rows x 11 columns]

# %% [markdown]
# Make the data frame visible by placing the data frame variable in a cell by itself.

# %%
df
# Out:
#      Unnamed: 0       brand brand_short     product product_short     hex  \
# 0             0  Maybelline          mb      Fit Me           fmf  f3cfb3
# 1             1  Maybelline          mb      Fit Me           fmf  ffe3c2
# 2             2  Maybelline          mb      Fit Me           fmf  ffe0cd
# 3             3  Maybelline          mb      Fit Me           fmf  ffd3be
# 4             4  Maybelline          mb      Fit Me           fmf  bd9584
# ..          ...         ...         ...         ...           ...     ...
# 620         620     L'Oréal          lo  True Match           tms  eecfba
# 621         621     L'Oréal          lo  True Match           tms  e8c7b8
# 622         622     L'Oréal          lo  True Match           tms  f0cbb9
# 623         623     L'Oréal          lo  True Match           tms  e9c4b1
# 624         624     L'Oréal          lo  True Match           tms  eabea1
#
#         H     S     V   L  group
# 0    26.0  0.26  0.95  86      2
# 1    32.0  0.24  1.00  92      2
# 2    23.0  0.20  1.00  91      2
# 3    19.0  0.25  1.00  88      2
# 4    18.0  0.30  0.74  65      2
# ..    ...   ...   ...  ..    ...
# 620  24.0  0.22  0.93  85      7
# 621  19.0  0.21  0.91  83      7
# 622  20.0  0.23  0.94  85      7
# 623  20.0  0.24  0.91  82      7
# 624  24.0  0.31  0.92  80      7
#
# [625 rows x 11 columns]

# %% [markdown]
# What columns are in your data frame? Use a function or method that shows all the columns.

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#      Unnamed: 0       brand brand_short     product product_short     hex  \
# 0             0  Maybelline          mb      Fit Me           fmf  f3cfb3
# 1             1  Maybelline          mb      Fit Me           fmf  ffe3c2
# 2             2  Maybelline          mb      Fit Me           fmf  ffe0cd
# 3             3  Maybelline          mb      Fit Me           fmf  ffd3be
# 4             4  Maybelline          mb      Fit Me           fmf  bd9584
# ..          ...         ...         ...         ...           ...     ...
# 620         620     L'Oréal          lo  True Match           tms  eecfba
# 621         621     L'Oréal          lo  True Match           tms  e8c7b8
# 622         622     L'Oréal          lo  True Match           tms  f0cbb9
# 623         623     L'Oréal          lo  True Match           tms  e9c4b1
# 624         624     L'Oréal          lo  True Match           tms  eabea1
#
#         H     S     V   L  group
# 0    26.0  0.26  0.95  86      2
# 1    32.0  0.24  1.00  92      2
# 2    23.0  0.20  1.00  91      2
# 3    19.0  0.25  1.00  88      2
# 4    18.0  0.30  0.74  65      2
# ..    ...   ...   ...  ..    ...
# 620  24.0  0.22  0.93  85      7
# 621  19.0  0.21  0.91  83      7
# 622  20.0  0.23  0.94  85      7
# 623  20.0  0.24  0.91  82      7
# 624  24.0  0.31  0.92  80      7
#
# [625 rows x 11 columns]

# %% [markdown]
# Write Python code to output the number of rows in your data frame.

# %%
print("Number of rows =", len(df))
# Out:
# Number of rows = 625

# %% [markdown]
# Write code to output a column from your data frame as a series. (Extract a column.)

# %%
series_product = df['product']
print(series_product)
# Out:
# 0          Fit Me
# 1          Fit Me
# 2          Fit Me
# 3          Fit Me
# 4          Fit Me
#           ...
# 620    True Match
# 621    True Match
# 622    True Match
# 623    True Match
# 624    True Match
# Name: product, Length: 625, dtype: object

# %% [markdown]
# ### Read the example below to **count** duplicates based on specific columns (e.g., 'Name' and 'Age')
#
# Check duplicates based on 'Name' and 'Age' columns (modify the subset for your own columns):
#
# `duplicates_subset = df.duplicated(subset=['Name', 'Age'])`
#
# Count the number of duplicates in the subset:
#
# `num_duplicates_subset = duplicates_subset.sum()`
#
# Display no. of duplicate rows based on your column(s):
#
# `print(f"\nNumber of duplicate rows based on 'Name' and 'Age': {num_duplicates_subset}")`

# %% [markdown]
# After reading the above, modify the code snippets to check for duplicate columns in your own data frame

# %%
duplicates_subset = df.duplicated(subset=['brand', 'product'])
num_duplicates_subset = duplicates_subset.sum()
print(f"\nNumber of duplicate rows based on 'brand' and 'product': {num_duplicates_subset}")
# Out:
# Number of duplicate rows based on 'brand' and 'product': 586

# %% [markdown]
# If any duplicates exist within a column, remove them with the `.drop_duplicates()` function

# %%
df.drop_duplicates(subset=['brand', 'product'])
# Out:
#      Unnamed: 0             brand brand_short                 product  \
# 0             0        Maybelline          mb                  Fit Me
# 40           40      bareMinerals          bm                 barePRO
# 69           69      Estée Lauder          el             Double Wear
# 111         111            Revlon          rv               ColorStay
# 133         133           L'Oréal          lo             Infalliable
# 155         155  Covergirl + Olay          oc          Simply Ageless
# 167         167             Fenty          fe              PRO FILT'R
# 207         207              Iman          im          Second to None
# 215         215    Beauty Bakerie          bb             #1 CAKE MIX
# 245         245          Black Up          bu         Matifying Fluid
# 263         263        Black Opal          bo              True Color
# 275         275    Laws of Nature          ln             Foxy Finish
# 292         292           Lancôme          lc             Teint Idole
# 332         332               MAC          ma              Studio Fix
# 374         374       Bobbi Brown          br          Skin Long-Wear
# 404         404  Make Up For Ever          mu                Ultra HD
# 444         444   Hegai and Ester          he           Photo Perfect
# 454         454     House of Tara          ht                Oil Free
# 465         465     Trim & Prissy          tp         Flawless Finish
# 471         471     Trim & Prissy          tp                Hi - Def
# 478         478         Elsas Pro          ep           Full Coverage
# 489         489             Kuddy          ku              Matte Wear
# 494         494               RMK         rmk              RMK Liquid
# 503         503         Addiction          ad          The Foundation
# 520         520        Shu Uemera          su        Petal Skin Fluid
# 531         531          Shiseido          sh            Synchro Skin
# 537         537              Kate          ka  Secret Skin Maker Zero
# 543         543              IPSA          ip       Liquid Foundation
# 549         549              Dior          di        Diorskin Forever
# 555         555              NARS          na            Velvet Matte
# 568         568             Lakmé          la        Invisible Finish
# 572         572          Colorbar          cb           Perfect Match
# 575         575    Bharat & Doris          bd       Liquid Foundation
# 582         582            Olivia          ol              Foundation
# 586         586       Blue Heaven          bh                X Factor
# 588         588     Lotus Herbals          lh         Make-Up Ecostay
# 592         592             Nykaa          ny              SKINgenius
# 597         597        Maybelline          mb            Fit Me Matte
# 611         611           L'Oréal          lo              True Match
#
#     product_short     hex     H     S     V   L  group
# 0             fmf  f3cfb3  26.0  0.26  0.95  86      2
# 40            pro  edceb2  28.0  0.25  0.93  85      2
# 69             dw  ffd6ba  24.0  0.27  1.00  89      2
# 111            cs  f9caac  23.0  0.31  0.98  85      2
# 133           ipm  f3c6a2  27.0  0.33  0.95  83      2
# 155            sa  e1ad81   NaN   NaN   NaN  75      2
# 167            pf  fde9de  21.0  0.12  0.99  94      0
# 207            sn  e1bea4  26.0  0.27  0.88  80      3
# 215            cm  532e1e  18.0  0.64  0.33  24      3
# 245            mf  eed1b5  29.0  0.24  0.93  86      3
# 263            tc  b77d57  24.0  0.52  0.72  65      3
# 275            ff  a66c4b  22.0  0.55  0.65  51      3
# 292            ti  fdece4  19.0  0.10  0.99  95      4
# 332           sff  d8b593  30.0  0.32  0.85  76      4
# 374           slw  f5e0c8  32.0  0.18  0.96  90      4
# 404           uhd  f9e3d5  23.0  0.14  0.98  92      1
# 444            pp  f6a762  28.0  0.60  0.96  75      5
# 454           off  ae7748  28.0  0.59  0.68  55      5
# 465           fff  e2ac7c  28.0  0.45  0.89  75      5
# 471           hdf  fcd1a7  30.0  0.34  0.99  87      5
# 478           fcf  815d51  15.0  0.37  0.51  43      5
# 489           mwf  c78660  22.0  0.52  0.78  62      5
# 494            lf  fcdba8  36.0  0.33  0.99  89      6
# 503            tf  ffdcbe  28.0  0.25  1.00  90      6
# 520           psf  e9a986  21.0  0.42  0.91  75      6
# 531            ss  edb899  22.0  0.35  0.93  79      6
# 537           ssm  f7d5bb  26.0  0.24  0.97  88      6
# 543            lf  edc69f  30.0  0.33  0.93  83      6
# 549            df  e6c6ad  26.0  0.25  0.90  82      6
# 555            vm  fad8a7  35.0  0.33  0.98  88      6
# 568            if  c39d76  30.0  0.39  0.76  68      7
# 572            pm  cd9d77  27.0  0.42  0.80  69      7
# 575            lf  d7ac7a  32.0  0.43  0.84  73      7
# 582            fo  eb893e  26.0  0.74  0.92  67      7
# 586            xf  ebb08a  24.0  0.41  0.92  77      7
# 588           mue  eec1a2  24.0  0.32  0.93  82      7
# 592            sg  cb9070  21.0  0.45  0.80  65      7
# 597           fmm  f7d1bc  21.0  0.24  0.97  87      7
# 611           tms  693720  19.0  0.70  0.41  29      7

# %% [markdown]
# Write Python code to output the number of rows in your data frame.

# %%
print("The number of rows is" , len(duplicates_subset))
# Out:
# The number of rows is 625

# %% [markdown]
# Compare the new value with the first time you outputted the number of rows above. Is it more, less, or the same?

# %% [markdown]
# It is the same.

# %% [markdown]
# Create a subset of the data that matches a specific string in a column. That is, extract all rows of the original data frame that contain a specific string in one of the columns. Save the resulting data frame to a variable. (Add more cells if needed)

# %%
string = 'NARS'
column = 'brand'
subset_df = df[df[column].str.contains(string, na=False)]
print(subset_df)
# Out:
#      Unnamed: 0 brand brand_short       product product_short     hex     H  \
# 555         555  NARS          na  Velvet Matte            vm  fad8a7  35.0
# 556         556  NARS          na  Velvet Matte            vm  efbf99  27.0
# 557         557  NARS          na  Velvet Matte            vm  f6d0a1  33.0
# 558         558  NARS          na  Velvet Matte            vm  ecb98c  28.0
# 559         559  NARS          na  Velvet Matte            vm  e7ab74  29.0
# 560         560  NARS          na  Velvet Matte            vm  e6b685  30.0
# 561         561  NARS          na  Velvet Matte            vm  dd9e6d  26.0
# 562         562  NARS          na  Velvet Matte            vm  e4aa7c  27.0
# 563         563  NARS          na  Velvet Matte            vm  dfa575  27.0
# 564         564  NARS          na  Velvet Matte            vm  da9b5a  30.0
# 565         565  NARS          na  Velvet Matte            vm  e4a36a  28.0
# 566         566  NARS          na  Velvet Matte            vm  ca8a55  27.0
# 567         567  NARS          na  Velvet Matte            vm  ce8440  29.0
#
#         S     V   L  group
# 555  0.33  0.98  88      6
# 556  0.36  0.94  81      6
# 557  0.35  0.96  86      6
# 558  0.41  0.93  79      6
# 559  0.50  0.91  75      6
# 560  0.42  0.90  78      6
# 561  0.51  0.87  71      6
# 562  0.46  0.89  74      6
# 563  0.48  0.87  73      6
# 564  0.59  0.85  69      6
# 565  0.54  0.89  72      6
# 566  0.58  0.79  63      6
# 567  0.69  0.81  62      6

# %% [markdown]
# Output the length of the resulting data frame (the subset of your data for which the conditional was true).

# %%
print(len(subset_df))
# Out:
# 13

# %% [markdown]
# Output the first ten rows of your data set, the last ten rows of your data set, and a random ten rows of your data set (a sample of your data).

# %%
print("First ten rows")
print(df.head(10))
# Out:
# First ten rows
#    Unnamed: 0       brand brand_short product product_short     hex     H  \
# 0           0  Maybelline          mb  Fit Me           fmf  f3cfb3  26.0
# 1           1  Maybelline          mb  Fit Me           fmf  ffe3c2  32.0
# 2           2  Maybelline          mb  Fit Me           fmf  ffe0cd  23.0
# 3           3  Maybelline          mb  Fit Me           fmf  ffd3be  19.0
# 4           4  Maybelline          mb  Fit Me           fmf  bd9584  18.0
# 5           5  Maybelline          mb  Fit Me           fmf  eabda6  20.0
# 6           6  Maybelline          mb  Fit Me           fmf  fbd2ad  28.0
# 7           7  Maybelline          mb  Fit Me           fmf  e2b597  24.0
# 8           8  Maybelline          mb  Fit Me           fmf  e4b38e  26.0
# 9           9  Maybelline          mb  Fit Me           fmf  b2856f  20.0
#
#       S     V   L  group
# 0  0.26  0.95  86      2
# 1  0.24  1.00  92      2
# 2  0.20  1.00  91      2
# 3  0.25  1.00  88      2
# 4  0.30  0.74  65      2
# 5  0.29  0.92  80      2
# 6  0.31  0.98  87      2
# 7  0.33  0.89  77      2
# 8  0.38  0.89  77      2
# 9  0.38  0.70  60      2

# %%
print("Last ten rows")
print(df.tail(10))
# Out:
# Last ten rows
#      Unnamed: 0    brand brand_short     product product_short     hex     H  \
# 615         615  L'Oréal          lo  True Match           tms  ddb496  25.0
# 616         616  L'Oréal          lo  True Match           tms  eebfa3  22.0
# 617         617  L'Oréal          lo  True Match           tms  e7cbb5  26.0
# 618         618  L'Oréal          lo  True Match           tms  dcb29a  22.0
# 619         619  L'Oréal          lo  True Match           tms  f0c7b3  20.0
# 620         620  L'Oréal          lo  True Match           tms  eecfba  24.0
# 621         621  L'Oréal          lo  True Match           tms  e8c7b8  19.0
# 622         622  L'Oréal          lo  True Match           tms  f0cbb9  20.0
# 623         623  L'Oréal          lo  True Match           tms  e9c4b1  20.0
# 624         624  L'Oréal          lo  True Match           tms  eabea1  24.0
#
#         S     V   L  group
# 615  0.32  0.87  76      7
# 616  0.32  0.93  81      7
# 617  0.22  0.91  84      7
# 618  0.30  0.86  76      7
# 619  0.25  0.94  83      7
# 620  0.22  0.93  85      7
# 621  0.21  0.91  83      7
# 622  0.23  0.94  85      7
# 623  0.24  0.91  82      7
# 624  0.31  0.92  80      7

# %%
print("Random ten rows")
print(df.sample(n=10))
# Out:
# Random ten rows
#      Unnamed: 0             brand brand_short         product product_short  \
# 134         134           L'Oréal          lo     Infalliable           ipm
# 8             8        Maybelline          mb          Fit Me           fmf
# 174         174             Fenty          fe      PRO FILT'R            pf
# 560         560              NARS          na    Velvet Matte            vm
# 407         407  Make Up For Ever          mu        Ultra HD           uhd
# 41           41      bareMinerals          bm         barePRO           pro
# 167         167             Fenty          fe      PRO FILT'R            pf
# 607         607        Maybelline          mb    Fit Me Matte           fmm
# 400         400       Bobbi Brown          br  Skin Long-Wear           slw
# 518         518         Addiction          ad  The Foundation            tf
#
#         hex     H     S     V   L  group
# 134  e5ad8b  23.0  0.39  0.90  75      2
# 8    e4b38e  26.0  0.38  0.89  77      2
# 174  e8bfa3  24.0  0.30  0.91  80      0
# 560  e6b685  30.0  0.42  0.90  78      6
# 407  f7c3b3  14.0  0.28  0.97  83      1
# 41   f0cba1  32.0  0.33  0.94  84      2
# 167  fde9de  21.0  0.12  0.99  94      0
# 607  ebbf93  30.0  0.37  0.92  81      7
# 400  7e462d  19.0  0.64  0.49  36      4
# 518  c38355  25.0  0.56  0.76  61      6

# %% [markdown]
# ## Bonus
#
# You may want to refer to the [Pandas Cheat Sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf).

# %% [markdown]
# Sort your data frame by a particular column and output the result.

# %%
column = 'hex'
sorted_df = df.sort_values(by=column)
print(sorted_df)
# Out:
#      Unnamed: 0           brand brand_short          product product_short  \
# 282         282  Laws of Nature          ln      Foxy Finish            ff
# 262         262        Black Up          bu  Matifying Fluid            mf
# 331         331         Lancôme          lc      Teint Idole            ti
# 261         261        Black Up          bu  Matifying Fluid            mf
# 39           39      Maybelline          mb           Fit Me           fmf
# ..          ...             ...         ...              ...           ...
# 504         504       Addiction          ad   The Foundation            tf
# 337         337             MAC          ma       Studio Fix           sff
# 503         503       Addiction          ad   The Foundation            tf
# 2             2      Maybelline          mb           Fit Me           fmf
# 1             1      Maybelline          mb           Fit Me           fmf
#
#         hex     H     S     V   L  group
# 282  321407  18.0  0.86  0.20  11      3
# 262  352315  26.0  0.60  0.21  16      3
# 331  391b11  15.0  0.70  0.22  14      4
# 261  3b2218  17.0  0.59  0.23  16      3
# 39   3f2018  12.0  0.62  0.25  16      2
# ..      ...   ...   ...   ...  ..    ...
# 504  ffd8b9  27.0  0.27  1.00  89      6
# 337  ffdbc2  25.0  0.24  1.00  90      4
# 503  ffdcbe  28.0  0.25  1.00  90      6
# 2    ffe0cd  23.0  0.20  1.00  91      2
# 1    ffe3c2  32.0  0.24  1.00  92      2
#
# [625 rows x 11 columns]

# %% [markdown]
# Pick a column in your data set with numeric data (integers or floats). Output the mean (average) and median of that column.

# %%
column = 'group'
mean_value = df[column].mean()
median_value = df[column].median()
print("Mean(average) =", mean_value)
print("Median =", median_value)
# Out:
# Mean(average) = 3.472
# Median = 3.0
